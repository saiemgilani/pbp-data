# %%
from numpy.core.fromnumeric import mean
from flask import jsonify
import pandas as pd
import numpy as np
import json
import re
import http
import xgboost as xgb
import time
import urllib
from urllib.error import URLError, HTTPError, ContentTooShortError
from datetime import datetime
from itertools import chain, starmap
# %load_ext jupyternotify

# years completed 2002-2020
years_arr = 2020
def download(url, num_retries=5): 
#     print('Downloading:', url)
    try: 
        
        html = urllib.request.urlopen(url).read()
    except (URLError, HTTPError, ContentTooShortError, http.client.HTTPException, http.client.IncompleteRead) as e: 
        print('Download error:', url)
        html = None 
        if num_retries > 0: 
            if hasattr(e, 'code') and 500 <= e.code < 600: 
                time.sleep(10)
                # recursively retry 5xx HTTP errors 
                return download(url, num_retries - 1) 
        if num_retries > 0: 
            if e == http.client.IncompleteRead: 
                time.sleep(10)
                return download(url, num_retries - 1)
    return html

def flatten_json_iterative(dictionary, sep = '.', ind_start = 0):
    """Flattening a nested json file"""

    def unpack_one(parent_key, parent_value):
        """Unpack one level (only one) of nesting in json file"""
        # Unpacking one level        
        if isinstance(parent_value, dict):
            for key, value in parent_value.items():
                t1 = parent_key + sep + key
                yield t1, value
        elif isinstance(parent_value, list):
            i = ind_start 
            for value in parent_value:
                t2 = parent_key + sep +str(i) 
                i += 1
                yield t2, value
        else:
            yield parent_key, parent_value    

            
    # Continue iterating the unpack_one function until the terminating condition is satisfied
    while True:
        # Continue unpacking the json file until all values are atomic elements (aka neither a dictionary nor a list)
        dictionary = dict(chain.from_iterable(starmap(unpack_one, dictionary.items())))
        # Terminating condition: none of the values in the json file are a dictionary or a list
        if not any(isinstance(value, dict) for value in dictionary.values()) and \
           not any(isinstance(value, list) for value in dictionary.values()):
            break

    return dictionary

def wbb_pbp(gameId):
        """cfb_pbp()
        Pull the game by id
        Data from API endpoints:
        * college-football/playbyplay
        * college-football/summary
        """
        # play by play
        pbp_url = "http://cdn.espn.com/core/womens-college-basketball/playbyplay?gameId={}&xhr=1&render=false&userab=18".format(gameId)
        pbp_resp = download(url=pbp_url)
        pbp_txt = {}
        
        if pbp_resp is not None:
            pbp_txt['teams'] = np.array([])
            pbp_txt['id'] = np.array([])
            pbp_txt['competitions'] = np.array([])
            pbp_txt['season'] = np.array([])
            pbp_txt['header'] = {}
            pbp_txt['pickcenter'] = np.array([])
            pbp_txt['broadcasts'] = np.array([])
            pbp_txt['videos'] = np.array([])
            pbp_txt['standings'] = np.array([])
            pbp_txt['boxscore'] = np.array([])
            pbp_txt['espnWP'] = np.array([])
            pbp_txt['gameInfo'] = np.array([])
            pbp_txt['season'] = np.array([])
            pbp_txt['timeouts'] = {}
            pbp_d = json.loads(pbp_resp)
            pbp_txt = pbp_d['gamepackageJSON']
            pbp_txt['gameId'] = pbp_d['gameId']
            # summary endpoint for pickcenter array
            summary_url = "http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/summary?event={}".format(gameId)
            summary_resp = download(url=summary_url)
            summary = json.loads(summary_resp)
            if 'pickcenter' in summary:
                summary_txt = summary['pickcenter']
            else:
                summary_txt = {}
            # ESPN's win probability
            wp = "winprobability"
            if wp in summary:
                espnWP = summary["winprobability"]
            else:
                espnWP = np.array([])

            if 'news' in pbp_txt.keys():
                del pbp_txt['news']
            if 'shop' in pbp_txt.keys():
                del pbp_txt['shop']
            pbp_txt['gameInfo'] = pbp_txt['header']['competitions'][0]
            pbp_txt['season'] = pbp_txt['header']['season']['year']
            pbp_txt['pickcenter'] = summary_txt
            pbp_txt['espnWP'] = espnWP
            # Home and Away identification variables
            homeTeamId = int(pbp_txt['header']['competitions'][0]['competitors'][0]['team']['id'])
            awayTeamId = int(pbp_txt['header']['competitions'][0]['competitors'][1]['team']['id'])
            homeTeamMascot = str(pbp_txt['header']['competitions'][0]['competitors'][0]['team']['name'])
            awayTeamMascot = str(pbp_txt['header']['competitions'][0]['competitors'][1]['team']['name'])
            homeTeamName = str(pbp_txt['header']['competitions'][0]['competitors'][0]['team']['location'])
            awayTeamName = str(pbp_txt['header']['competitions'][0]['competitors'][1]['team']['location'])
            homeTeamAbbrev = str(pbp_txt['header']['competitions'][0]['competitors'][0]['team']['abbreviation'])
            awayTeamAbbrev = str(pbp_txt['header']['competitions'][0]['competitors'][1]['team']['abbreviation'])
            homeTeamNameAlt = re.sub("Stat(.+)", "St", str(homeTeamName))
            awayTeamNameAlt = re.sub("Stat(.+)", "St", str(awayTeamName))

            if len(pbp_txt['espnWP']) > 1:
                pbp_txt['espnWP'] = espnWP
            else:
                pbp_txt['espnWP'] = espnWP
            pbp_txt['plays_mod'] = []
            for play in pbp_txt['plays']:
                p = flatten_json_iterative(play)
                pbp_txt['plays_mod'].append(p)
            pbp_txt['plays'] = pd.json_normalize(pbp_txt,'plays_mod')
            if len(pbp_txt['plays'])>1:
                pbp_txt['plays']['season'] = pbp_txt['header']['season']['year']
                pbp_txt['plays']['seasonType'] = pbp_txt['header']['season']['type']
                pbp_txt['plays']["awayTeamId"] = awayTeamId
                pbp_txt['plays']["awayTeamName"] = str(awayTeamName)
                pbp_txt['plays']["awayTeamMascot"] = str(awayTeamMascot)
                pbp_txt['plays']["awayTeamAbbrev"] = str(awayTeamAbbrev)
                pbp_txt['plays']["awayTeamNameAlt"] = str(awayTeamNameAlt)
                pbp_txt['plays']["homeTeamId"] = homeTeamId
                pbp_txt['plays']["homeTeamName"] = str(homeTeamName)
                pbp_txt['plays']["homeTeamMascot"] = str(homeTeamMascot)
                pbp_txt['plays']["homeTeamAbbrev"] = str(homeTeamAbbrev)
                pbp_txt['plays']["homeTeamNameAlt"] = str(homeTeamNameAlt)
                # Spread definition
                pbp_txt['plays']["homeTeamSpread"] = 2.5
                if len(pbp_txt['pickcenter']) > 1:
                    if 'spread' in pbp_txt['pickcenter'][1].keys():
                        gameSpread =  pbp_txt['pickcenter'][1]['spread']
                        homeFavorite = pbp_txt['pickcenter'][1]['homeTeamOdds']['favorite']
                    else:
                        gameSpread =  pbp_txt['pickcenter'][0]['spread']
                        homeFavorite = pbp_txt['pickcenter'][0]['homeTeamOdds']['favorite']

                else:
                    gameSpread = 2.5
                    homeFavorite = True
                pbp_txt['plays']["gameSpread"] = abs(gameSpread)
                pbp_txt['plays']["homeTeamSpread"] = np.where(homeFavorite == True, abs(gameSpread), -1*abs(gameSpread))
                pbp_txt['homeTeamSpread'] = np.where(homeFavorite == True, abs(gameSpread), -1*abs(gameSpread))
                pbp_txt['plays']["homeFavorite"] = homeFavorite
                pbp_txt['plays']["gameSpread"] = gameSpread
                pbp_txt['plays']["homeFavorite"] = homeFavorite

                pbp_txt['plays'] = pd.DataFrame(pbp_txt['plays'])
                pbp_txt['plays']['season'] = pbp_txt['header']['season']['year']
                pbp_txt['plays']['seasonType'] = pbp_txt['header']['season']['type']
                pbp_txt['plays']["homeTeamId"] = homeTeamId
                pbp_txt['plays']["awayTeamId"] = awayTeamId
                pbp_txt['plays']["homeTeamName"] = str(homeTeamName)
                pbp_txt['plays']["awayTeamName"] = str(awayTeamName)
                pbp_txt['plays']["homeTeamMascot"] = str(homeTeamMascot)
                pbp_txt['plays']["awayTeamMascot"] = str(awayTeamMascot)
                pbp_txt['plays']["homeTeamAbbrev"] = str(homeTeamAbbrev)
                pbp_txt['plays']["awayTeamAbbrev"] = str(awayTeamAbbrev)
                pbp_txt['plays']["homeTeamNameAlt"] = str(homeTeamNameAlt)
                pbp_txt['plays']["awayTeamNameAlt"] = str(awayTeamNameAlt)
                pbp_txt['plays']['period.number'] = pbp_txt['plays']['period.number'].apply(lambda x: int(x))
                #----- Figuring out Timeouts ---------
                pbp_txt['timeouts'] = {}
                pbp_txt['timeouts'][homeTeamId] = {"1": [], "2": []}
                pbp_txt['timeouts'][awayTeamId] = {"1": [], "2": []}
                pbp_txt['homeTeamSpread'] = np.where(homeFavorite == True, abs(gameSpread), -1*abs(gameSpread))
                pbp_txt['plays']["gameSpread"] = abs(gameSpread)
                pbp_txt['plays']["homeTeamSpread"] = np.where(homeFavorite == True, abs(gameSpread), -1*abs(gameSpread))
                pbp_txt['plays']["homeFavorite"] = homeFavorite
                pbp_txt['plays']["gameSpread"] = gameSpread
                pbp_txt['plays']["homeFavorite"] = homeFavorite

                #----- Time ---------------
                pbp_txt['plays']['clock.mm'] = pbp_txt['plays']['clock.displayValue'].str.split(pat=':')
                pbp_txt['plays'][['clock.minutes','clock.seconds']] = pbp_txt['plays']['clock.mm'].to_list()
                pbp_txt['plays']['half'] = np.where(pbp_txt['plays']['period.number'] <= 2, "1","2")
                pbp_txt['plays']['lag_half'] = pbp_txt['plays']['half'].shift(1)
                pbp_txt['plays']['lead_half'] = pbp_txt['plays']['half'].shift(-1)

                pbp_txt['plays']['game_play_number'] = np.arange(len(pbp_txt['plays']))+1
                pbp_txt['plays']['text'] = pbp_txt['plays']['text'].astype(str)
                pbp_txt['plays']['id'] = pbp_txt['plays']['id'].apply(lambda x: int(x))
                del pbp_txt['plays']['clock.mm']
            else:
                if len(pbp_txt['pickcenter']) > 1:
                    gameSpread = pbp_txt['pickcenter'][1]['spread']
                    homeFavorite = pbp_txt['pickcenter'][1]['homeTeamOdds']['favorite']
                else:
                    gameSpread = 2.5
                    homeFavorite = True
                pbp_txt['homeTeamSpread'] = np.where(homeFavorite == True, abs(gameSpread), -1*abs(gameSpread))


            pbp_json = {
                "gameId": pbp_txt['gameId'],
                "plays" : pbp_txt['plays'].to_dict(orient='records'),
                "winprobability" : np.array(pbp_txt['winprobability']).tolist(),
                "boxscore" : pbp_txt['boxscore'],
                "header" : pbp_txt['header'],
                "homeTeamSpread" : np.array(pbp_txt['homeTeamSpread']).tolist(),
                "broadcasts" : np.array(pbp_txt['broadcasts']).tolist(),
                "videos" : np.array(pbp_txt['videos']).tolist(),
                "standings" : pbp_txt['standings'],
                "pickcenter" : np.array(pbp_txt['pickcenter']).tolist(),
                "espnWP" : np.array(pbp_txt['espnWP']).tolist(),
                "gameInfo" : np.array(pbp_txt['gameInfo']).tolist(),
                "season" : np.array(pbp_txt['season']).tolist()
            }
            return pbp_json, pbp_json['season']
        else:
            
            pass
        
    
schedule = pd.read_csv('wbb/schedules/wbb_games_info_{}.csv'.format(years_arr), encoding='latin-1')
schedule = schedule.sort_values(by=['season', 'date'], ascending = False)

games = schedule[(schedule['season']==years_arr)&(schedule['status.type.name']=='STATUS_FINAL')].reset_index()['id']
print(f"Number of Games: {len(games)}, first gameId: {games[0]}")
g, y = wbb_pbp(gameId = games[0])
# for key in g.keys():
#     print(f"{key}: {type(g[key])}")    
json.dumps(g,indent=4)
print(g.keys())
print(g['pickcenter'])
print(g['homeTeamSpread'])
print(pd.DataFrame(g['plays']))
y
# Out:
# The jupyternotify extension is already loaded. To reload it, use:
#   %reload_ext jupyternotify
# Number of Games: 5434, first gameId: 401211959
# dict_keys(['gameId', 'plays', 'winprobability', 'boxscore', 'header', 'homeTeamSpread', 'broadcasts', 'videos', 'standings', 'pickcenter', 'espnWP', 'gameInfo', 'season'])
# {}
# 2.5
#      shootingPlay sequenceNumber period.displayValue  period.number  \
# 0            True      101906201         1st Quarter              1
# 1           False      101906202         1st Quarter              1
# 2           False      101908101         1st Quarter              1
# 3           False      101908201         1st Quarter              1
# 4            True      101908501         1st Quarter              1
# ..            ...            ...                 ...            ...
# 361          True      104999105         4th Quarter              4
# 362         False      104999106         4th Quarter              4
# 363         False      104999701         4th Quarter              4
# 364         False      104999702         4th Quarter              4
# 365         False      104999901         4th Quarter              4
#
#      homeScore  scoringPlay clock.displayValue team.id type.id  \
# 0            0        False               9:37    2169     558
# 1            0        False               9:37    2415     587
# 2            0        False               9:18    2415     598
# 3            0        False               9:17    2169     607
# 4            0        False               9:14    2169     558
# ..         ...          ...                ...     ...     ...
# 361         64        False               0:08    2415     540
# 362         64        False               0:08    2169     587
# 363         64        False               0:02    2169     519
# 364         64        False               0:02    2169     598
# 365         64        False               0:00     NaN     402
#
#               type.text  ...  homeTeamNameAlt  homeTeamSpread gameSpread  \
# 0              JumpShot  ...        Morgan St             2.5        2.5
# 1     Defensive Rebound  ...        Morgan St             2.5        2.5
# 2    Lost Ball Turnover  ...        Morgan St             2.5        2.5
# 3                 Steal  ...        Morgan St             2.5        2.5
# 4              JumpShot  ...        Morgan St             2.5        2.5
# ..                  ...  ...              ...             ...        ...
# 361       MadeFreeThrow  ...        Morgan St             2.5        2.5
# 362   Defensive Rebound  ...        Morgan St             2.5        2.5
# 363        PersonalFoul  ...        Morgan St             2.5        2.5
# 364  Lost Ball Turnover  ...        Morgan St             2.5        2.5
# 365            End Game  ...        Morgan St             2.5        2.5
#
#      homeFavorite clock.minutes clock.seconds  half  lag_half  lead_half  \
# 0            True             9            37     1       NaN          1
# 1            True             9            37     1         1          1
# 2            True             9            18     1         1          1
# 3            True             9            17     1         1          1
# 4            True             9            14     1         1          1
# ..            ...           ...           ...   ...       ...        ...
# 361          True             0            08     2         2          2
# 362          True             0            08     2         2          2
# 363          True             0            02     2         2          2
# 364          True             0            02     2         2          2
# 365          True             0            00     2         2        NaN
#
#     game_play_number
# 0                  1
# 1                  2
# 2                  3
# 3                  4
# 4                  5
# ..               ...
# 361              362
# 362              363
# 363              364
# 364              365
# 365              366
#
# [366 rows x 37 columns]
# 2020

# %%
# %%notify
# # 2888,5077, 5091 no header
# i = 5092
# for game in games[i:]:
#     print(f"Working on game {i+1} of {len(games)}, gameId: {games[i]}")
#     if len(str(game))<9:
#         i+=1
#         continue
#     try:
#         g, y = wbb_pbp(gameId=game)
#     except (TypeError) as e:
#         print("TypeError: yo", e)
#         g, y = wbb_pbp(gameId=game)
#     fp = "wbb/{}/{}.json".format(y, game)
#     with open(fp,'w') as f:
#         json.dump(g, f, indent=4, sort_keys=False)
# #     time.sleep(1)
#     i+=1
# Out:
# Working on game 5093 of 5434, gameId: 401178647
# Working on game 5094 of 5434, gameId: 401175503
# Working on game 5095 of 5434, gameId: 401174215
# Working on game 5096 of 5434, gameId: 401171097
# Working on game 5097 of 5434, gameId: 401171096
# Working on game 5098 of 5434, gameId: 401169175
# Working on game 5099 of 5434, gameId: 401177197
# Working on game 5100 of 5434, gameId: 401179995
# Working on game 5101 of 5434, gameId: 401180103
# Working on game 5102 of 5434, gameId: 401180549
# Working on game 5103 of 5434, gameId: 401174528
# Working on game 5104 of 5434, gameId: 401179469
# Working on game 5105 of 5434, gameId: 401177181
# Working on game 5106 of 5434, gameId: 401179654
# Working on game 5107 of 5434, gameId: 401177495
# Working on game 5108 of 5434, gameId: 401173853
# Working on game 5109 of 5434, gameId: 401171095
# Working on game 5110 of 5434, gameId: 401169173
# Working on game 5111 of 5434, gameId: 401177311
# Working on game 5112 of 5434, gameId: 401166792
# Working on game 5113 of 5434, gameId: 401166966
# Working on game 5114 of 5434, gameId: 401179560
# Working on game 5115 of 5434, gameId: 401184376
# Working on game 5116 of 5434, gameId: 401166940
# Working on game 5117 of 5434, gameId: 401166778
# Working on game 5118 of 5434, gameId: 401171094
# Working on game 5119 of 5434, gameId: 401176203
# Working on game 5120 of 5434, gameId: 401184375
# Working on game 5121 of 5434, gameId: 401178416
# Working on game 5122 of 5434, gameId: 401177414
# Working on game 5123 of 5434, gameId: 401177349
# Working on game 5124 of 5434, gameId: 401176811
# Working on game 5125 of 5434, gameId: 401176021
# Working on game 5126 of 5434, gameId: 401175524
# Working on game 5127 of 5434, gameId: 401171091
# Working on game 5128 of 5434, gameId: 401167002
# Working on game 5129 of 5434, gameId: 401166989
# Working on game 5130 of 5434, gameId: 401171092
# Working on game 5131 of 5434, gameId: 401177285
# Working on game 5132 of 5434, gameId: 401180127
# Working on game 5133 of 5434, gameId: 401178947
# Working on game 5134 of 5434, gameId: 401178504
# Working on game 5135 of 5434, gameId: 401177333
# Working on game 5136 of 5434, gameId: 401177326
# Working on game 5137 of 5434, gameId: 401177319
# Working on game 5138 of 5434, gameId: 401177064
# Working on game 5139 of 5434, gameId: 401176833
# Working on game 5140 of 5434, gameId: 401176812
# Working on game 5141 of 5434, gameId: 401176344
# Working on game 5142 of 5434, gameId: 401176277
# Working on game 5143 of 5434, gameId: 401175606
# Working on game 5144 of 5434, gameId: 401175418
# Working on game 5145 of 5434, gameId: 401174214
# Working on game 5146 of 5434, gameId: 401173352
# Working on game 5147 of 5434, gameId: 401171093
# Working on game 5148 of 5434, gameId: 401171090
# Working on game 5149 of 5434, gameId: 401169171
# Working on game 5150 of 5434, gameId: 401169172
# Working on game 5151 of 5434, gameId: 401178946
# Working on game 5152 of 5434, gameId: 401178503
# Working on game 5153 of 5434, gameId: 401178067
# Working on game 5154 of 5434, gameId: 401177264
# Working on game 5155 of 5434, gameId: 401178066
# Working on game 5156 of 5434, gameId: 401172093
# Working on game 5157 of 5434, gameId: 401177661
# Working on game 5158 of 5434, gameId: 401174527
# Working on game 5159 of 5434, gameId: 401173970
# Working on game 5160 of 5434, gameId: 401169166
# Working on game 5161 of 5434, gameId: 401178502
# Working on game 5162 of 5434, gameId: 401174210
# Working on game 5163 of 5434, gameId: 401179794
# Working on game 5164 of 5434, gameId: 401178793
# Working on game 5165 of 5434, gameId: 401178465
# Working on game 5166 of 5434, gameId: 401177398
# Working on game 5167 of 5434, gameId: 401179084
# Working on game 5168 of 5434, gameId: 401178795
# Working on game 5169 of 5434, gameId: 401178501
# Working on game 5170 of 5434, gameId: 401174024
# Working on game 5171 of 5434, gameId: 401169170
# Working on game 5172 of 5434, gameId: 401173927
# Working on game 5173 of 5434, gameId: 401174135
# Working on game 5174 of 5434, gameId: 401171089
# Working on game 5175 of 5434, gameId: 401178794
# Working on game 5176 of 5434, gameId: 401177664
# Working on game 5177 of 5434, gameId: 401177494
# Working on game 5178 of 5434, gameId: 401174526
# Download error: http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/summary?event=401174526
# Download error: http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/summary?event=401174526
# Working on game 5179 of 5434, gameId: 401174083
# Working on game 5180 of 5434, gameId: 401173991
# Working on game 5181 of 5434, gameId: 401173814
# Working on game 5182 of 5434, gameId: 401179725
# Working on game 5183 of 5434, gameId: 401166768
# Working on game 5184 of 5434, gameId: 401180229
# Working on game 5185 of 5434, gameId: 401177370
# Working on game 5186 of 5434, gameId: 401177256
# Working on game 5187 of 5434, gameId: 401175873
# Working on game 5188 of 5434, gameId: 401169169
# Working on game 5189 of 5434, gameId: 401169168
# Working on game 5190 of 5434, gameId: 401166978
# Working on game 5191 of 5434, gameId: 401180114
# Working on game 5192 of 5434, gameId: 401178646
# Working on game 5193 of 5434, gameId: 401178065
# Working on game 5194 of 5434, gameId: 401178064
# Working on game 5195 of 5434, gameId: 401178063
# Working on game 5196 of 5434, gameId: 401177663
# Working on game 5197 of 5434, gameId: 401177343
# Working on game 5198 of 5434, gameId: 401176750
# Working on game 5199 of 5434, gameId: 401175813
# Working on game 5200 of 5434, gameId: 401174213
# Working on game 5201 of 5434, gameId: 401169167
# Working on game 5202 of 5434, gameId: 401179086
# Working on game 5203 of 5434, gameId: 401178645
# Working on game 5204 of 5434, gameId: 401177662
# Working on game 5205 of 5434, gameId: 401176154
# Working on game 5206 of 5434, gameId: 401175890
# Working on game 5207 of 5434, gameId: 401174212
# Working on game 5208 of 5434, gameId: 401174211
# Working on game 5209 of 5434, gameId: 401171088
# Working on game 5210 of 5434, gameId: 401180093
# Working on game 5211 of 5434, gameId: 401179577
# Working on game 5212 of 5434, gameId: 401178062
# Working on game 5213 of 5434, gameId: 401177444
# Working on game 5214 of 5434, gameId: 401176680
# Working on game 5215 of 5434, gameId: 401178456
# Working on game 5216 of 5434, gameId: 401174525
# Working on game 5217 of 5434, gameId: 401174082
# Working on game 5218 of 5434, gameId: 401173852
# Working on game 5219 of 5434, gameId: 401177493
# Working on game 5220 of 5434, gameId: 401176810
# Working on game 5221 of 5434, gameId: 401174524
# Working on game 5222 of 5434, gameId: 401174523
# Working on game 5223 of 5434, gameId: 401174521
# Working on game 5224 of 5434, gameId: 401177174
# Working on game 5225 of 5434, gameId: 401179585
# Working on game 5226 of 5434, gameId: 401176135
# Working on game 5227 of 5434, gameId: 401176123
# Working on game 5228 of 5434, gameId: 401174522
# Working on game 5229 of 5434, gameId: 401167027
# Working on game 5230 of 5434, gameId: 401179528
# Working on game 5231 of 5434, gameId: 401179486
# Working on game 5232 of 5434, gameId: 401176808
# Working on game 5233 of 5434, gameId: 401176807
# Working on game 5234 of 5434, gameId: 401171086
# Working on game 5235 of 5434, gameId: 401169164
# Working on game 5236 of 5434, gameId: 401177293
# Working on game 5237 of 5434, gameId: 401177284
# Working on game 5238 of 5434, gameId: 401183530
# Working on game 5239 of 5434, gameId: 401179826
# Working on game 5240 of 5434, gameId: 401178644
# Working on game 5241 of 5434, gameId: 401177185
# Working on game 5242 of 5434, gameId: 401175393
# Working on game 5243 of 5434, gameId: 401175297
# Working on game 5244 of 5434, gameId: 401171087
# Working on game 5245 of 5434, gameId: 401169165
# Working on game 5246 of 5434, gameId: 401169163
# Working on game 5247 of 5434, gameId: 401171085
# Working on game 5248 of 5434, gameId: 401180025
# Working on game 5249 of 5434, gameId: 401176654
# Working on game 5250 of 5434, gameId: 401176169
# Working on game 5251 of 5434, gameId: 401179732
# Working on game 5252 of 5434, gameId: 401178792
# Working on game 5253 of 5434, gameId: 401177602
# Working on game 5254 of 5434, gameId: 401180102
# Working on game 5255 of 5434, gameId: 401179631
# Working on game 5256 of 5434, gameId: 401177659
# Working on game 5257 of 5434, gameId: 401174209
# Working on game 5258 of 5434, gameId: 401177660
# Working on game 5259 of 5434, gameId: 401175502
# Working on game 5260 of 5434, gameId: 401173902
# Working on game 5261 of 5434, gameId: 401176202
# Working on game 5262 of 5434, gameId: 401174208
# Working on game 5263 of 5434, gameId: 401178945
# Working on game 5264 of 5434, gameId: 401176809
# Working on game 5265 of 5434, gameId: 401166926
# Working on game 5266 of 5434, gameId: 401178415
# Working on game 5267 of 5434, gameId: 401176804
# Working on game 5268 of 5434, gameId: 401173990
# Working on game 5269 of 5434, gameId: 401173926
# Working on game 5270 of 5434, gameId: 401177270
# Working on game 5271 of 5434, gameId: 401176805
# Working on game 5272 of 5434, gameId: 401177263
# Working on game 5273 of 5434, gameId: 401179684
# Working on game 5274 of 5434, gameId: 401178472
# Working on game 5275 of 5434, gameId: 401178061
# Working on game 5276 of 5434, gameId: 401178060
# Working on game 5277 of 5434, gameId: 401176806
# Working on game 5278 of 5434, gameId: 401176276
# Working on game 5279 of 5434, gameId: 401174207
# Working on game 5280 of 5434, gameId: 401174205
# Working on game 5281 of 5434, gameId: 401167015
# Working on game 5282 of 5434, gameId: 401166952
# Working on game 5283 of 5434, gameId: 401171084
# Working on game 5284 of 5434, gameId: 401174520
# Working on game 5285 of 5434, gameId: 401177406
# Working on game 5286 of 5434, gameId: 401177658
# Working on game 5287 of 5434, gameId: 401177657
# Working on game 5288 of 5434, gameId: 401179324
# Working on game 5289 of 5434, gameId: 401178643
# Working on game 5290 of 5434, gameId: 401177086
# Working on game 5291 of 5434, gameId: 401173969
# Working on game 5292 of 5434, gameId: 401177413
# Working on game 5293 of 5434, gameId: 401178789
# Working on game 5294 of 5434, gameId: 401177656
# Working on game 5295 of 5434, gameId: 401175461
# Working on game 5296 of 5434, gameId: 401166747
# Working on game 5297 of 5434, gameId: 401179825
# Working on game 5298 of 5434, gameId: 401179559
# Working on game 5299 of 5434, gameId: 401176112
# Working on game 5300 of 5434, gameId: 401171083
# Working on game 5301 of 5434, gameId: 401179218
# Working on game 5302 of 5434, gameId: 401178642
# Working on game 5303 of 5434, gameId: 401178455
# Working on game 5304 of 5434, gameId: 401178059
# Working on game 5305 of 5434, gameId: 401175964
# Working on game 5306 of 5434, gameId: 401175417
# Working on game 5307 of 5434, gameId: 401171082
# Working on game 5308 of 5434, gameId: 401166760
# Working on game 5309 of 5434, gameId: 401178058
# Working on game 5310 of 5434, gameId: 401179612
# Working on game 5311 of 5434, gameId: 401178641
# Working on game 5312 of 5434, gameId: 401178500
# Working on game 5313 of 5434, gameId: 401177302
# Working on game 5314 of 5434, gameId: 401169162
# Working on game 5315 of 5434, gameId: 401169161
# Working on game 5316 of 5434, gameId: 401177369
# Working on game 5317 of 5434, gameId: 401174519
# Download error: http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/summary?event=401174519
# Download error: http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/summary?event=401174519
# Download error: http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/summary?event=401174519
# Working on game 5318 of 5434, gameId: 401174513
# Working on game 5319 of 5434, gameId: 401178012
# Working on game 5320 of 5434, gameId: 401177492
# Working on game 5321 of 5434, gameId: 401177386
# Working on game 5322 of 5434, gameId: 401183613
# Working on game 5323 of 5434, gameId: 401177355
# Working on game 5324 of 5434, gameId: 401174518
# Working on game 5325 of 5434, gameId: 401179527
# Working on game 5326 of 5434, gameId: 401177173
# Working on game 5327 of 5434, gameId: 401173351
# Working on game 5328 of 5434, gameId: 401166791
# Working on game 5329 of 5434, gameId: 401177017
# Working on game 5330 of 5434, gameId: 401171081
# Working on game 5331 of 5434, gameId: 401179824
# Working on game 5332 of 5434, gameId: 401179584
# Working on game 5333 of 5434, gameId: 401179321
# Working on game 5334 of 5434, gameId: 401177654
# Working on game 5335 of 5434, gameId: 401177470
# Working on game 5336 of 5434, gameId: 401177342
# Working on game 5337 of 5434, gameId: 401174516
# Working on game 5338 of 5434, gameId: 401174514
# Working on game 5339 of 5434, gameId: 401174204
# Working on game 5340 of 5434, gameId: 401173851
# Working on game 5341 of 5434, gameId: 401173813
# Working on game 5342 of 5434, gameId: 401169160
# Working on game 5343 of 5434, gameId: 401169159
# Working on game 5344 of 5434, gameId: 401167026
# Working on game 5345 of 5434, gameId: 401167001
# Working on game 5346 of 5434, gameId: 401179450
# Working on game 5347 of 5434, gameId: 401177043
# Working on game 5348 of 5434, gameId: 401166977
# Working on game 5349 of 5434, gameId: 401176153
# Working on game 5350 of 5434, gameId: 401166777
# Working on game 5351 of 5434, gameId: 401171076
# Working on game 5352 of 5434, gameId: 401171075
# Working on game 5353 of 5434, gameId: 401166965
# Working on game 5354 of 5434, gameId: 401171079
# Working on game 5355 of 5434, gameId: 401177292
# Working on game 5356 of 5434, gameId: 401180218
# Working on game 5357 of 5434, gameId: 401180199
# Working on game 5358 of 5434, gameId: 401179950
# Working on game 5359 of 5434, gameId: 401179738
# Working on game 5360 of 5434, gameId: 401179322
# Working on game 5361 of 5434, gameId: 401178944
# Working on game 5362 of 5434, gameId: 401178791
# Working on game 5363 of 5434, gameId: 401178790
# Working on game 5364 of 5434, gameId: 401178640
# Working on game 5365 of 5434, gameId: 401178639
# Working on game 5366 of 5434, gameId: 401178499
# Working on game 5367 of 5434, gameId: 401178057
# Working on game 5368 of 5434, gameId: 401177853
# Working on game 5369 of 5434, gameId: 401177626
# Working on game 5370 of 5434, gameId: 401176705
# Working on game 5371 of 5434, gameId: 401176653
# Working on game 5372 of 5434, gameId: 401176253
# Working on game 5373 of 5434, gameId: 401176201
# Working on game 5374 of 5434, gameId: 401176168
# Working on game 5375 of 5434, gameId: 401176020
# Working on game 5376 of 5434, gameId: 401175324
# Working on game 5377 of 5434, gameId: 401175296
# Working on game 5378 of 5434, gameId: 401174203
# Working on game 5379 of 5434, gameId: 401174202
# Working on game 5380 of 5434, gameId: 401174201
# Working on game 5381 of 5434, gameId: 401171080
# Working on game 5382 of 5434, gameId: 401171078
# Working on game 5383 of 5434, gameId: 401171077
# Working on game 5384 of 5434, gameId: 401171074
# Working on game 5385 of 5434, gameId: 401171073
# Working on game 5386 of 5434, gameId: 401169154
# Working on game 5387 of 5434, gameId: 401169153
# Working on game 5388 of 5434, gameId: 401167014
# Working on game 5389 of 5434, gameId: 401166988
# Working on game 5390 of 5434, gameId: 401166939
# Working on game 5391 of 5434, gameId: 401180317
# Working on game 5392 of 5434, gameId: 401179731
# Working on game 5393 of 5434, gameId: 401179323
# Working on game 5394 of 5434, gameId: 401178490
# Working on game 5395 of 5434, gameId: 401176134
# Working on game 5396 of 5434, gameId: 401176122
# Working on game 5397 of 5434, gameId: 401180305
# Working on game 5398 of 5434, gameId: 401179915
# Working on game 5399 of 5434, gameId: 401179364
# Working on game 5400 of 5434, gameId: 401179085
# Working on game 5401 of 5434, gameId: 401178943
# Working on game 5402 of 5434, gameId: 401178498
# Working on game 5403 of 5434, gameId: 401177655
# Working on game 5404 of 5434, gameId: 401177106
# Working on game 5405 of 5434, gameId: 401174200
# Working on game 5406 of 5434, gameId: 401174009
# Working on game 5407 of 5434, gameId: 401169158
# Working on game 5408 of 5434, gameId: 401169155
# Working on game 5409 of 5434, gameId: 401178056
# Working on game 5410 of 5434, gameId: 401174199
# Working on game 5411 of 5434, gameId: 401169157
# Working on game 5412 of 5434, gameId: 401178638
# Working on game 5413 of 5434, gameId: 401178055
# Working on game 5414 of 5434, gameId: 401175352
# Working on game 5415 of 5434, gameId: 401178054
# Working on game 5416 of 5434, gameId: 401177295
# Working on game 5417 of 5434, gameId: 401177325
# Working on game 5418 of 5434, gameId: 401175889
# Working on game 5419 of 5434, gameId: 401174023
# Working on game 5420 of 5434, gameId: 401173901
# Working on game 5421 of 5434, gameId: 401174515
# Working on game 5422 of 5434, gameId: 401177063
# Working on game 5423 of 5434, gameId: 401176803
# Working on game 5424 of 5434, gameId: 401178414
# Working on game 5425 of 5434, gameId: 401169156
# Working on game 5426 of 5434, gameId: 401180373
# Working on game 5427 of 5434, gameId: 401180007
# Working on game 5428 of 5434, gameId: 401178942
# Working on game 5429 of 5434, gameId: 401178497
# Working on game 5430 of 5434, gameId: 401177653
# Working on game 5431 of 5434, gameId: 401177255
# Working on game 5432 of 5434, gameId: 401175523
# Working on game 5433 of 5434, gameId: 401177277
# Working on game 5434 of 5434, gameId: 401178053
